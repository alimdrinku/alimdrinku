# %% [markdown]
# <a href="https://colab.research.google.com/github/alimdrinku/alimdrinku/blob/main/day02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# we already learned about string methods
#lets learn about data and data types
# day02

x=10 #int
y=12.5 #float
z=10-5j #10 is a real number and 5j is a imaginary

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# complex

# %%
isinstance(z,complex)
# Out:
# True

# %%
isinstance(x,int)
# Out:
# True

# %%
isinstance(y,int)
# Out:
# False

# %%
# int to float

a = float(x)
print(a)
# Out:
# 10.0

# %%
isinstance(a,float)
# Out:
# True

# %%
type(a)
# Out:
# float

# %%
# note that , int or float to int, float,complex canbe convert
#but complex to int or float is not possible

# %%
#lets try to get complex user intput

f = complex(input('Enter your complex number: '))
# Out:
# Enter your complex number: 1+2j

# %%
type(f)
# Out:
# complex

# %%
# bool

h = True
i= False

h
# Out:
# True
