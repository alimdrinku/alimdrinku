# %% [markdown]
# <a href="https://colab.research.google.com/github/alimdrinku/alimdrinku/blob/main/day01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lets learn python , i will show you how to write python basic codes , so let's start
# we will learn the most easy and common things in python : how to print something , here we go


print("This is your first day at programming world!")
# Out:
# This is your first day at programming world!

# %%
# lets see how about this ? see its totally working well,, okey lets see the whats next

print('this is my first code')
# Out:
# this is my first code

# %%
# lets learn about variables

var = 'im learning variables'
print(var)

#so you can see i put my data into a variables called var & printed it out by calling it in print function
# Out:
# im learning variables

# %%
#lets prctice what we already learned

my_name = 'tom'
my_age ='20'
my_id = '001001'
print('hello, my name is ' , my_name , 'my age is' , my_age , '. my id numur is ;', my_id)

my_id
# Out:
# hello, my name is  tom my age is 20 . my id numur is ; 001001
# '001001'

# %%
#lets learn how to use a function
x = 150 #global
def func1():
  x = 500 #local if have same name variable then local one is more powerfull
  print('the number is :', x)
  func1()
print('the acctual number is : ',x)
# Out:
# the acctual number is :  150

# %%
data= 'one day of codding'

#data.find('of')
data.find('at')
# Out:
# -1

# %%
#data.index('of')
data.index('at')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2703570068.py in <cell line: 0>()
#       1 #data.index('of')
# ----> 2 data.index('at')
#
# ValueError: substring not found

# %%
# day02

a='learning python is so much fun '

a.upper()
# Out:
# 'LEARNING PYTHON IS SO MUCH FUN '

# %%
a.lower()
# Out:
# 'learning python is so much fun '

# %%
a.title()
# Out:
# 'Learning Python Is So Much Fun '

# %%
a.split()[2]
# Out:
# 'is'

# %%
a.center(100)
# Out:
# '                                  learning python is so much fun                                    '

# %%
a.replace('python','data')
# Out:
# 'learning data is so much fun '

# %%
x=10
y=100
z=x*y
print('i have ', z, 'doller')
# Out:
# i have  1000 doller

# %%
print('i have {} taka '.format(z))
# Out:
# i have 1000 taka
